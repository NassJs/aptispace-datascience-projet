# %%
# Installation automatique des dépendances requises dans le noyau Jupyter actuel
# %pip install -r ../requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas>=2.0.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from -r ../requirements.txt (line 2)) (2.3.3)
# Requirement already satisfied: numpy>=1.24.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from -r ../requirements.txt (line 3)) (2.0.2)
# Requirement already satisfied: kagglehub>=0.3.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from -r ../requirements.txt (line 6)) (0.3.13)
# Requirement already satisfied: scikit-learn>=1.2.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from -r ../requirements.txt (line 9)) (1.6.1)
# Requirement already satisfied: tensorflow>=2.12.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from -r ../requirements.txt (line 10)) (2.20.0)
# Requirement already satisfied: matplotlib>=3.7.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from -r ../requirements.txt (line 13)) (3.9.4)
# Requirement already satisfied: seaborn>=0.12.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from -r ../requirements.txt (line 14)) (0.13.2)
# Requirement already satisfied: plotnine>=0.12.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from -r ../requirements.txt (line 15)) (0.13.6)
# Requirement already satisfied: ipykernel in /Users/nd/Library/Python/3.9/lib/python/site-packages (from -r ../requirements.txt (line 18)) (6.31.0)
# Requirement already satisfied: jupyter in /Users/nd/Library/Python/3.9/lib/python/site-packages (from -r ../requirements.txt (line 19)) (1.1.1)
# Requirement already satisfied: quarto in /Users/nd/Library/Python/3.9/lib/python/site-packages (from -r ../requirements.txt (line 20)) (0.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from pandas>=2.0.0->-r ../requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from pandas>=2.0.0->-r ../requirements.txt (line 2)) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from pandas>=2.0.0->-r ../requirements.txt (line 2)) (2026.2)
# Requirement already satisfied: pyyaml in /Users/nd/Library/Python/3.9/lib/python/site-packages (from kagglehub>=0.3.0->-r ../requirements.txt (line 6)) (6.0.3)
# Requirement already satisfied: packaging in /Users/nd/Library/Python/3.9/lib/python/site-packages (from kagglehub>=0.3.0->-r ../requirements.txt (line 6)) (26.2)
# Requirement already satisfied: tqdm in /Users/nd/Library/Python/3.9/lib/python/site-packages (from kagglehub>=0.3.0->-r ../requirements.txt (line 6)) (4.67.3)
# Requirement already satisfied: requests in /Users/nd/Library/Python/3.9/lib/python/site-packages (from kagglehub>=0.3.0->-r ../requirements.txt (line 6)) (2.32.5)
# Requirement already satisfied: joblib>=1.2.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from scikit-learn>=1.2.0->-r ../requirements.txt (line 9)) (1.5.3)
# Requirement already satisfied: scipy>=1.6.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from scikit-learn>=1.2.0->-r ../requirements.txt (line 9)) (1.13.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from scikit-learn>=1.2.0->-r ../requirements.txt (line 9)) (3.6.0)
# Requirement already satisfied: opt_einsum>=2.3.2 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 10)) (3.4.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 10)) (4.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 10)) (2.3.1)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 10)) (25.12.19)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 10)) (0.5.4)
# Requirement already satisfied: libclang>=13.0.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 10)) (18.1.1)
# Requirement already satisfied: protobuf>=5.28.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 10)) (6.33.6)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 10)) (0.7.0)
# Requirement already satisfied: keras>=3.10.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 10)) (3.10.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 10)) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 10)) (1.80.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 10)) (3.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 10)) (1.6.3)
# Requirement already satisfied: six>=1.12.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 10)) (1.15.0)
# Requirement already satisfied: h5py>=3.11.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 10)) (3.14.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 10)) (0.2.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 10)) (2.20.0)
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 10)) (58.0.4)
# Requirement already satisfied: cycler>=0.10 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 13)) (0.12.1)
# Requirement already satisfied: pillow>=8 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 13)) (11.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 13)) (4.60.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 13)) (1.4.7)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 13)) (6.5.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 13)) (3.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 13)) (1.3.0)
# Requirement already satisfied: mizani~=0.11.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from plotnine>=0.12.0->-r ../requirements.txt (line 15)) (0.11.4)
# Requirement already satisfied: statsmodels>=0.14.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from plotnine>=0.12.0->-r ../requirements.txt (line 15)) (0.14.6)
# Requirement already satisfied: comm>=0.1.1 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from ipykernel->-r ../requirements.txt (line 18)) (0.2.3)
# Requirement already satisfied: nest-asyncio>=1.4 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from ipykernel->-r ../requirements.txt (line 18)) (1.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from ipykernel->-r ../requirements.txt (line 18)) (5.8.1)
# Requirement already satisfied: psutil>=5.7 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from ipykernel->-r ../requirements.txt (line 18)) (7.2.2)
# Requirement already satisfied: jupyter-client>=8.0.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from ipykernel->-r ../requirements.txt (line 18)) (8.6.3)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from ipykernel->-r ../requirements.txt (line 18)) (5.15.0)
# Requirement already satisfied: ipython>=7.23.1 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from ipykernel->-r ../requirements.txt (line 18)) (8.18.1)
# Requirement already satisfied: tornado>=6.2 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from ipykernel->-r ../requirements.txt (line 18)) (6.5.5)
# Requirement already satisfied: pyzmq>=25 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from ipykernel->-r ../requirements.txt (line 18)) (27.1.0)
# Requirement already satisfied: appnope>=0.1.2 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from ipykernel->-r ../requirements.txt (line 18)) (0.1.4)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from ipykernel->-r ../requirements.txt (line 18)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from ipykernel->-r ../requirements.txt (line 18)) (1.8.20)
# Requirement already satisfied: nbconvert in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jupyter->-r ../requirements.txt (line 19)) (7.17.1)
# Requirement already satisfied: jupyterlab in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jupyter->-r ../requirements.txt (line 19)) (4.5.7)
# Requirement already satisfied: notebook in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jupyter->-r ../requirements.txt (line 19)) (7.5.6)
# Requirement already satisfied: ipywidgets in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jupyter->-r ../requirements.txt (line 19)) (8.1.8)
# Requirement already satisfied: jupyter-console in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jupyter->-r ../requirements.txt (line 19)) (6.6.3)
# Requirement already satisfied: nbclient in /Users/nd/Library/Python/3.9/lib/python/site-packages (from quarto->-r ../requirements.txt (line 20)) (0.10.2)
# Requirement already satisfied: nbformat in /Users/nd/Library/Python/3.9/lib/python/site-packages (from quarto->-r ../requirements.txt (line 20)) (5.10.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow>=2.12.0->-r ../requirements.txt (line 10)) (0.37.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.7.0->-r ../requirements.txt (line 13)) (3.23.1)
# Requirement already satisfied: pexpect>4.3 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 18)) (4.9.0)
# Requirement already satisfied: jedi>=0.16 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 18)) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 18)) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 18)) (2.20.0)
# Requirement already satisfied: decorator in /Users/nd/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 18)) (5.3.1)
# Requirement already satisfied: exceptiongroup in /Users/nd/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 18)) (1.3.1)
# Requirement already satisfied: stack-data in /Users/nd/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 18)) (0.6.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 18)) (0.8.7)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jupyter-client>=8.0.0->ipykernel->-r ../requirements.txt (line 18)) (8.7.1)
# Requirement already satisfied: platformdirs>=2.5 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->-r ../requirements.txt (line 18)) (4.4.0)
# Requirement already satisfied: namex in /Users/nd/Library/Python/3.9/lib/python/site-packages (from keras>=3.10.0->tensorflow>=2.12.0->-r ../requirements.txt (line 10)) (0.1.0)
# Requirement already satisfied: optree in /Users/nd/Library/Python/3.9/lib/python/site-packages (from keras>=3.10.0->tensorflow>=2.12.0->-r ../requirements.txt (line 10)) (0.19.1)
# Requirement already satisfied: rich in /Users/nd/Library/Python/3.9/lib/python/site-packages (from keras>=3.10.0->tensorflow>=2.12.0->-r ../requirements.txt (line 10)) (15.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 18)) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/nd/Library/Python/3.9/lib/python/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 18)) (0.7.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from requests->kagglehub>=0.3.0->-r ../requirements.txt (line 6)) (3.15)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from requests->kagglehub>=0.3.0->-r ../requirements.txt (line 6)) (2026.4.22)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from requests->kagglehub>=0.3.0->-r ../requirements.txt (line 6)) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from requests->kagglehub>=0.3.0->-r ../requirements.txt (line 6)) (2.6.3)
# Requirement already satisfied: patsy>=0.5.6 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from statsmodels>=0.14.0->plotnine>=0.12.0->-r ../requirements.txt (line 15)) (1.0.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from tensorboard~=2.20.0->tensorflow>=2.12.0->-r ../requirements.txt (line 10)) (0.7.2)
# Requirement already satisfied: markdown>=2.6.8 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from tensorboard~=2.20.0->tensorflow>=2.12.0->-r ../requirements.txt (line 10)) (3.9)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from tensorboard~=2.20.0->tensorflow>=2.12.0->-r ../requirements.txt (line 10)) (3.1.8)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow>=2.12.0->-r ../requirements.txt (line 10)) (3.0.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from ipywidgets->jupyter->-r ../requirements.txt (line 19)) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from ipywidgets->jupyter->-r ../requirements.txt (line 19)) (3.0.16)
# Requirement already satisfied: tomli>=1.2.2 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 19)) (2.4.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 19)) (2.18.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 19)) (2.3.1)
# Requirement already satisfied: jinja2>=3.0.3 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 19)) (3.1.6)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 19)) (0.28.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 19)) (2.28.0)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 19)) (2.0.5)
# Requirement already satisfied: notebook-shim>=0.2 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 19)) (0.2.4)
# Requirement already satisfied: anyio in /Users/nd/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /Users/nd/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (25.1.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (0.5.4)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (0.25.0)
# Requirement already satisfied: websocket-client>=1.7 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (1.9.0)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (0.18.1)
# Requirement already satisfied: overrides>=5.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (7.7.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (0.12.1)
# Requirement already satisfied: argon2-cffi-bindings in /Users/nd/Library/Python/3.9/lib/python/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (25.1.0)
# Requirement already satisfied: jsonschema[format-nongpl]>=4.18.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (4.25.1)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (0.1.1)
# Requirement already satisfied: referencing in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (0.36.2)
# Requirement already satisfied: rfc3339-validator in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (0.1.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (4.0.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (2025.9.1)
# Requirement already satisfied: attrs>=22.2.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (26.1.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (0.27.1)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (24.11.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (1.1.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (3.0.0)
# Requirement already satisfied: uri-template in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (1.3.0)
# Requirement already satisfied: fqdn in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (1.5.1)
# Requirement already satisfied: isoduration in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (20.11.0)
# Requirement already satisfied: babel>=2.10 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (0.14.0)
# Requirement already satisfied: beautifulsoup4 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 19)) (4.14.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 19)) (3.2.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 19)) (1.5.1)
# Requirement already satisfied: bleach[css]!=5.0.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 19)) (6.2.0)
# Requirement already satisfied: jupyterlab-pygments in /Users/nd/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 19)) (0.3.0)
# Requirement already satisfied: defusedxml in /Users/nd/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 19)) (0.7.1)
# Requirement already satisfied: webencodings in /Users/nd/Library/Python/3.9/lib/python/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r ../requirements.txt (line 19)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r ../requirements.txt (line 19)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from nbformat->quarto->-r ../requirements.txt (line 20)) (2.21.2)
# Requirement already satisfied: lark>=1.2.2 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (2.0.0)
# Requirement already satisfied: pycparser in /Users/nd/Library/Python/3.9/lib/python/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (2.23)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from beautifulsoup4->nbconvert->jupyter->-r ../requirements.txt (line 19)) (2.8.3)
# Requirement already satisfied: arrow>=0.15.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 19)) (1.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from rich->keras>=3.10.0->tensorflow>=2.12.0->-r ../requirements.txt (line 10)) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow>=2.12.0->-r ../requirements.txt (line 10)) (0.1.2)
# Requirement already satisfied: executing>=1.2.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 18)) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/nd/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 18)) (0.2.3)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/nd/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 18)) (3.0.1)
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 📊 Étape 4 : Visualisation Multidimensionnelle (Squelette Étudiant)
#
# Cette étape correspond au quatrième chapitre du cours. L'objectif est de concevoir des représentations visuelles premium pour identifier des tendances et insights clés à l'aide de votre package personnalisé de tracé `src.utils_viz`.

# %% [markdown]
# ### 1. Préparation de l'environnement

# %%
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sys.path.append(os.path.abspath('..'))
from src import data_clean as dc
from src import utils_viz as uv

# Activation du style premium personnalisé (light ou dark)
uv.set_custom_style(theme='light')
# %matplotlib inline
print("Librairies de visualisation prêtes !")
# Out:
# Librairies de visualisation prêtes !

# %% [markdown]
# ### 2. Chargement du dataset enrichi

# %%
df = pd.read_csv("../data/processed/ai_student_cleaned.csv")

# Le dataset "ai_student_cleaned" ne contient pas de colonne temporelle :
# on saute donc l'étape pd.to_datetime() et dc.feature_engineering().
print(f"Dimensions : {df.shape}")
df.head()
# Out:
# Dimensions : (50000, 20)
#    Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0      100001     Humanities        Senior             2.418
# 1      100002        Medical        Junior             3.821
# 2      100003       Business      Freshman             3.398
# 3      100004       Business        Senior             3.789
# 4      100005           STEM     Sophomore             3.635
#
#    Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0               23.31       Copywriting/Drafting                 Beginner
# 1                1.12                   Ideation                 Advanced
# 2               21.26        Summarizing_Reading                 Beginner
# 3                1.82       Copywriting/Drafting             Intermediate
# 4                9.29  Debugging/Troubleshooting                 Advanced
#
#    Tool_Diversity  Paid_Subscription  Traditional_Study_Hours  \
# 0               1               True                     8.13
# 1               5              False                    16.65
# 2               2              False                    10.35
# 3               4              False                    15.23
# 4               4              False                    12.55
#
#    Perceived_AI_Dependency   Institutional_Policy  Anxiety_Level_During_Exams  \
# 0                        5  Allowed_With_Citation                           6
# 1                        3  Allowed_With_Citation                           9
# 2                        5             Strict_Ban                           9
# 3                        2  Allowed_With_Citation                           2
# 4                        4  Allowed_With_Citation                           4
#
#    Post_Semester_GPA  Skill_Retention_Score Burnout_Risk_Level  \
# 0              2.393                  86.44               High
# 1              3.696                  69.39                Low
# 2              3.499                  73.93             Medium
# 3              4.000                  63.58             Medium
# 4              3.798                 100.00             Medium
#
#    Secteur_IA_Adoption_Rate  Avg_Salary_Index  Recommended_Study_Hours_Week  \
# 0                      0.52               0.9                            10
# 1                      0.61               1.5                            18
# 2                      0.74               1.2                            12
# 3                      0.74               1.2                            12
# 4                      0.87               1.4                            15
#
#    High_Stakes_Exams
# 0              False
# 1               True
# 2              False
# 3              False
# 4               True

# %% [markdown]
# ### 3. Tracés et analyses graphiques
#
# #### A. Distribution univariée
#
# **À COMPLÉTER PAR L'ÉTUDIANT :**
# Tracez la distribution d'une variable clé du dataset avec `uv.plot_histogram`.

# %%
# A. Distribution univariée d'une variable clé : GPA post-semestre
uv.plot_histogram(df, "Post_Semester_GPA")

# %% [markdown]
# #### B. Carte de chaleur des corrélations
#
# **À COMPLÉTER PAR L'ÉTUDIANT :**
# Visualisez graphiquement les corrélations de Pearson à l'aide de `uv.plot_correlation_matrix`.

# %%
# B. Carte de chaleur des corrélations sur l'ensemble des colonnes numériques
uv.plot_correlation_matrix(df)

# %% [markdown]
# #### C. Comparaison bivariée par catégorie
#
# **À COMPLÉTER PAR L'ÉTUDIANT :**
# Générez une analyse bivariée (variable numérique par catégorie) avec `uv.plot_boxplot`.

# %%
# C. Comparaison bivariée : GPA post-semestre selon la filière
uv.plot_boxplot(df, x="Major_Category", y="Post_Semester_GPA")
