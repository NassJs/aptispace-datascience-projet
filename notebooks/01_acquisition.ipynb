# %%
# Installation automatique des dépendances requises dans le noyau Jupyter actuel
# %pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: pandas>=2.0.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from -r ../requirements.txt (line 4)) (3.0.3)
# Requirement already satisfied: numpy>=1.24.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from -r ../requirements.txt (line 5)) (2.4.5)
# Requirement already satisfied: scikit-learn>=1.2.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from -r ../requirements.txt (line 10)) (1.8.0)
# Requirement already satisfied: tensorflow>=2.12.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from -r ../requirements.txt (line 15)) (2.21.0)
# Requirement already satisfied: opencv-python>=4.8.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from -r ../requirements.txt (line 16)) (4.13.0.92)
# Collecting ultralytics>=8.0.0
#   Using cached ultralytics-8.4.53-py3-none-any.whl (1.3 MB)
# Requirement already satisfied: matplotlib>=3.7.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from -r ../requirements.txt (line 22)) (3.10.9)
# Requirement already satisfied: seaborn>=0.12.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from -r ../requirements.txt (line 23)) (0.13.2)
# Collecting plotly>=5.18.0
#   Using cached plotly-6.7.0-py3-none-any.whl (9.9 MB)
# Requirement already satisfied: plotnine>=0.12.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from -r ../requirements.txt (line 25)) (0.15.4)
# Requirement already satisfied: streamlit>=1.30.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from -r ../requirements.txt (line 30)) (1.57.0)
# Collecting python-dotenv>=1.0.0
#   Using cached python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Requirement already satisfied: jupyter in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from -r ../requirements.txt (line 40)) (1.1.1)
# Requirement already satisfied: ipykernel in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from -r ../requirements.txt (line 41)) (7.2.0)
# Requirement already satisfied: quarto in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from -r ../requirements.txt (line 42)) (0.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from pandas>=2.0.0->-r ../requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from pandas>=2.0.0->-r ../requirements.txt (line 4)) (2026.2)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn>=1.2.0->-r ../requirements.txt (line 10)) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn>=1.2.0->-r ../requirements.txt (line 10)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn>=1.2.0->-r ../requirements.txt (line 10)) (3.6.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 15)) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 15)) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 15)) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 15)) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 15)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 15)) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 15)) (3.4.0)
# Requirement already satisfied: packaging in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 15)) (26.2)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 15)) (6.33.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 15)) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 15)) (82.0.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 15)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 15)) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 15)) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 15)) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 15)) (1.80.0)
# Requirement already satisfied: keras>=3.12.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 15)) (3.14.1)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 15)) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 15)) (0.5.4)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from ultralytics>=8.0.0->-r ../requirements.txt (line 17)) (12.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from ultralytics>=8.0.0->-r ../requirements.txt (line 17)) (6.0.3)
# Collecting torch>=1.8.0
#   Using cached torch-2.12.0-cp311-cp311-win_amd64.whl (123.0 MB)
# Collecting torchvision>=0.9.0
#   Using cached torchvision-0.27.0-cp311-cp311-win_amd64.whl (3.7 MB)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from ultralytics>=8.0.0->-r ../requirements.txt (line 17)) (7.2.2)
# Collecting polars>=0.20.0
#   Using cached polars-1.40.1-py3-none-any.whl (828 kB)
# Collecting ultralytics-thop>=2.0.18
#   Using cached ultralytics_thop-2.0.19-py3-none-any.whl (28 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 22)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 22)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 22)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 22)) (1.5.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 22)) (3.3.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from plotly>=5.18.0->-r ../requirements.txt (line 24)) (2.21.2)
# Requirement already satisfied: mizani~=0.14.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from plotnine>=0.12.0->-r ../requirements.txt (line 25)) (0.14.4)
# Requirement already satisfied: statsmodels>=0.14.6 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from plotnine>=0.12.0->-r ../requirements.txt (line 25)) (0.14.6)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from streamlit>=1.30.0->-r ../requirements.txt (line 30)) (6.1.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from streamlit>=1.30.0->-r ../requirements.txt (line 30)) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from streamlit>=1.30.0->-r ../requirements.txt (line 30)) (7.1.4)
# Requirement already satisfied: click<9,>=7.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from streamlit>=1.30.0->-r ../requirements.txt (line 30)) (8.4.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from streamlit>=1.30.0->-r ../requirements.txt (line 30)) (3.1.50)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from streamlit>=1.30.0->-r ../requirements.txt (line 30)) (0.9.2)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from streamlit>=1.30.0->-r ../requirements.txt (line 30)) (22.0.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from streamlit>=1.30.0->-r ../requirements.txt (line 30)) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from streamlit>=1.30.0->-r ../requirements.txt (line 30)) (0.10.2)
# Requirement already satisfied: starlette>=0.40.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from streamlit>=1.30.0->-r ../requirements.txt (line 30)) (1.0.1)
# Requirement already satisfied: uvicorn>=0.30.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from streamlit>=1.30.0->-r ../requirements.txt (line 30)) (0.47.0)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from streamlit>=1.30.0->-r ../requirements.txt (line 30)) (0.7.1)
# Requirement already satisfied: anyio>=4.0.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from streamlit>=1.30.0->-r ../requirements.txt (line 30)) (4.13.0)
# Requirement already satisfied: python-multipart>=0.0.10 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from streamlit>=1.30.0->-r ../requirements.txt (line 30)) (0.0.29)
# Requirement already satisfied: websockets>=12.0.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from streamlit>=1.30.0->-r ../requirements.txt (line 30)) (16.0)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from streamlit>=1.30.0->-r ../requirements.txt (line 30)) (2.2.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from streamlit>=1.30.0->-r ../requirements.txt (line 30)) (6.0.0)
# Requirement already satisfied: notebook in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jupyter->-r ../requirements.txt (line 40)) (7.5.6)
# Requirement already satisfied: jupyter-console in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jupyter->-r ../requirements.txt (line 40)) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jupyter->-r ../requirements.txt (line 40)) (7.17.1)
# Requirement already satisfied: ipywidgets in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jupyter->-r ../requirements.txt (line 40)) (8.1.8)
# Requirement already satisfied: jupyterlab in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jupyter->-r ../requirements.txt (line 40)) (4.5.7)
# Requirement already satisfied: comm>=0.1.1 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from ipykernel->-r ../requirements.txt (line 41)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from ipykernel->-r ../requirements.txt (line 41)) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from ipykernel->-r ../requirements.txt (line 41)) (9.13.0)
# Requirement already satisfied: jupyter-client>=8.8.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from ipykernel->-r ../requirements.txt (line 41)) (8.8.0)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from ipykernel->-r ../requirements.txt (line 41)) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from ipykernel->-r ../requirements.txt (line 41)) (0.2.2)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from ipykernel->-r ../requirements.txt (line 41)) (1.6.0)
# Requirement already satisfied: pyzmq>=25 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from ipykernel->-r ../requirements.txt (line 41)) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from ipykernel->-r ../requirements.txt (line 41)) (6.5.5)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from ipykernel->-r ../requirements.txt (line 41)) (5.15.0)
# Requirement already satisfied: nbformat in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from quarto->-r ../requirements.txt (line 42)) (5.10.4)
# Requirement already satisfied: nbclient in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from quarto->-r ../requirements.txt (line 42)) (0.10.4)
# Requirement already satisfied: jinja2 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.30.0->-r ../requirements.txt (line 30)) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.30.0->-r ../requirements.txt (line 30)) (4.26.0)
# Requirement already satisfied: idna>=2.8 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from anyio>=4.0.0->streamlit>=1.30.0->-r ../requirements.txt (line 30)) (3.15)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from astunparse>=1.6.0->tensorflow>=2.12.0->-r ../requirements.txt (line 15)) (0.47.0)
# Requirement already satisfied: colorama in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from click<9,>=7.0->streamlit>=1.30.0->-r ../requirements.txt (line 30)) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.30.0->-r ../requirements.txt (line 30)) (4.0.12)
# Requirement already satisfied: decorator>=5.1.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 41)) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 41)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 41)) (0.20.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 41)) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 41)) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 41)) (0.6.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel->-r ../requirements.txt (line 41)) (4.9.6)
# Requirement already satisfied: rich in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.12.0->tensorflow>=2.12.0->-r ../requirements.txt (line 15)) (15.0.0)
# Requirement already satisfied: namex in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.12.0->tensorflow>=2.12.0->-r ../requirements.txt (line 15)) (0.1.0)
# Requirement already satisfied: optree in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.12.0->tensorflow>=2.12.0->-r ../requirements.txt (line 15)) (0.19.1)
# Collecting polars-runtime-32==1.40.1
#   Using cached polars_runtime_32-1.40.1-cp310-abi3-win_amd64.whl (51.8 MB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow>=2.12.0->-r ../requirements.txt (line 15)) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow>=2.12.0->-r ../requirements.txt (line 15)) (2.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow>=2.12.0->-r ../requirements.txt (line 15)) (2026.4.22)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from statsmodels>=0.14.6->plotnine>=0.12.0->-r ../requirements.txt (line 25)) (1.0.2)
# Requirement already satisfied: filelock in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics>=8.0.0->-r ../requirements.txt (line 17)) (3.29.0)
# Collecting setuptools
#   Downloading setuptools-81.0.0-py3-none-any.whl (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 9.6 MB/s eta 0:00:00
# Collecting sympy>=1.13.3
#   Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Collecting networkx>=2.5.1
#   Using cached networkx-3.6.1-py3-none-any.whl (2.1 MB)
# Collecting fsspec>=0.8.5
#   Using cached fsspec-2026.4.0-py3-none-any.whl (203 kB)
# Requirement already satisfied: h11>=0.8 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from uvicorn>=0.30.0->streamlit>=1.30.0->-r ../requirements.txt (line 30)) (0.16.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets->jupyter->-r ../requirements.txt (line 40)) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets->jupyter->-r ../requirements.txt (line 40)) (3.0.16)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 40)) (2.3.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 40)) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 40)) (2.3.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 40)) (2.18.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 40)) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 40)) (0.2.4)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from nbformat->quarto->-r ../requirements.txt (line 42)) (2.21.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 40)) (4.14.3)
# Requirement already satisfied: bleach[css]!=5.0.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 40)) (5.0.1)
# Requirement already satisfied: defusedxml in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 40)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 40)) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 40)) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 40)) (3.2.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 40)) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r ../requirements.txt (line 40)) (0.5.1)
# Requirement already satisfied: tinycss2<1.2,>=1.1.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r ../requirements.txt (line 40)) (1.1.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.30.0->-r ../requirements.txt (line 30)) (5.0.3)
# Requirement already satisfied: httpcore==1.* in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r ../requirements.txt (line 40)) (1.0.9)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 41)) (0.8.7)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.30.0->-r ../requirements.txt (line 30)) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.30.0->-r ../requirements.txt (line 30)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.30.0->-r ../requirements.txt (line 30)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.30.0->-r ../requirements.txt (line 30)) (0.30.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 40)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 40)) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 40)) (0.5.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 40)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 40)) (0.25.0)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 40)) (3.0.3)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 40)) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 40)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 40)) (1.9.0)
# Requirement already satisfied: babel>=2.10 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 40)) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 40)) (0.14.0)
# Requirement already satisfied: wcwidth in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 41)) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 41)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 41)) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 41)) (0.2.3)
# Collecting mpmath<1.4,>=1.1.0
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->-r ../requirements.txt (line 40)) (2.8.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from rich->keras>=3.12.0->tensorflow>=2.12.0->-r ../requirements.txt (line 15)) (4.2.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 40)) (25.1.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 40)) (2.0.4)
# Requirement already satisfied: rfc3339-validator in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 40)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 40)) (0.1.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow>=2.12.0->-r ../requirements.txt (line 15)) (0.1.2)
# Requirement already satisfied: fqdn in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.30.0->-r ../requirements.txt (line 30)) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.30.0->-r ../requirements.txt (line 30)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.30.0->-r ../requirements.txt (line 30)) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.30.0->-r ../requirements.txt (line 30)) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.30.0->-r ../requirements.txt (line 30)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.30.0->-r ../requirements.txt (line 30)) (25.10.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 40)) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 40)) (3.0)
# Requirement already satisfied: lark>=1.2.2 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.30.0->-r ../requirements.txt (line 30)) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\dearm\appdata\local\programs\python\python311\lib\site-packages (from isoduration->jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.30.0->-r ../requirements.txt (line 30)) (1.4.0)
# Installing collected packages: mpmath, sympy, setuptools, python-dotenv, polars-runtime-32, plotly, networkx, fsspec, torch, polars, ultralytics-thop, torchvision, ultralytics
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 82.0.1
#     Uninstalling setuptools-82.0.1:
#       Successfully uninstalled setuptools-82.0.1
# Successfully installed fsspec-2026.4.0 mpmath-1.3.0 networkx-3.6.1 plotly-6.7.0 polars-1.40.1 polars-runtime-32-1.40.1 python-dotenv-1.2.2 setuptools-81.0.0 sympy-1.14.0 torch-2.12.0 torchvision-0.27.0 ultralytics-8.4.53 ultralytics-thop-2.0.19
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # 📥 Étape 1 : Acquisition des Données & Multi-Sources (Squelette Étudiant)
#
# Cette étape correspond au premier chapitre du pipeline de Data Science. L'objectif est d'identifier, d'importer et de consolider vos jeux de données bruts issus de différentes sources (fichiers CSV locaux, requêtes API, bases de données, etc.).

# %% [markdown]
# ### 1. Initialisation de l'environnement

# %%
import os
import sys
import pandas as pd
import numpy as np

# Ajout du dossier parent au chemin de recherche des modules
sys.path.append(os.path.abspath('..'))

print("Libraries importées avec succès ! Prêt pour l'étape d'Acquisition des Données.")
# Out:
# Libraries importées avec succès ! Prêt pour l'étape d'Acquisition des Données.

# %% [markdown]
# ### 2. Chargement de la source de données principale
#
# **À COMPLÉTER PAR L'ÉTUDIANT :**
# Chargez votre jeu de données principal (par exemple un fichier CSV stocké dans `data/raw/`).

# %%
# Spécifiez le chemin vers votre jeu de données principal
main_data_path = '../data/raw/ai_student_impact_dataset (1).csv'

# TODO: Charger le dataset à l'aide de Pandas
df_main = pd.read_csv(main_data_path)

# Affichez la taille et les premières lignes
print(f"Dimensions du dataset principal : {df_main.shape}")
df_main.head()
# Out:
# Dimensions du dataset principal : (50000, 16)
#    Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0      100001     Humanities        Senior             2.418
# 1      100002        Medical        Junior             3.821
# 2      100003       Business      Freshman             3.398
# 3      100004       Business        Senior             3.789
# 4      100005           STEM     Sophomore             3.635
#
#    Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0               23.31       Copywriting/Drafting                 Beginner
# 1                1.12                   Ideation                 Advanced
# 2               21.26        Summarizing_Reading                 Beginner
# 3                1.82       Copywriting/Drafting             Intermediate
# 4                9.29  Debugging/Troubleshooting                 Advanced
#
#    Tool_Diversity  Paid_Subscription  Traditional_Study_Hours  \
# 0               1               True                     8.13
# 1               5              False                    16.65
# 2               2              False                    10.35
# 3               4              False                    15.23
# 4               4              False                    12.55
#
#    Perceived_AI_Dependency   Institutional_Policy  Anxiety_Level_During_Exams  \
# 0                        5  Allowed_With_Citation                           6
# 1                        3  Allowed_With_Citation                           9
# 2                        5             Strict_Ban                           9
# 3                        2  Allowed_With_Citation                           2
# 4                        4  Allowed_With_Citation                           4
#
#    Post_Semester_GPA  Skill_Retention_Score Burnout_Risk_Level
# 0              2.393                  86.44               High
# 1              3.696                  69.39                Low
# 2              3.499                  73.93             Medium
# 3              4.000                  63.58             Medium
# 4              3.798                 100.00             Medium

# %% [markdown]
# ### 3. Intégration de données secondaires (Multi-Sources)
#
# **À COMPLÉTER PAR L'ÉTUDIANT :**
# Mettez en place la récupération de vos données complémentaires (par exemple, appels d'API fictifs ou réels, données météo, géographiques, ou financiers complémentaires).

# %%
# TODO: Récupérer/générer ou charger vos données secondaires
# Exemple fictif : création d'un DataFrame complémentaire avec des catégories/labels
categories_info = pd.DataFrame({
    'category': ['A', 'B', 'C'],
    'description': ['Premium', 'Standard', 'Basique'],
    'coef_multiplicateur': [1.5, 1.0, 0.8]
})

print("Données secondaires prêtes :")
categories_info.head()
# Out:
# Données secondaires prêtes :
#   category description  coef_multiplicateur
# 0        A     Premium                  1.5
# 1        B    Standard                  1.0
# 2        C     Basique                  0.8

# %% [markdown]
# ### 4. Fusion des sources (Optionnel)
#
# **À COMPLÉTER PAR L'ÉTUDIANT :**
# Associez vos différentes sources de données en utilisant des jointures (`pd.merge`) pertinentes.

# %%
# TODO: Effectuer la jointure de vos tables si nécessaire
df_merged = pd.merge(df_main, categories_info, on='category', how='left')
df_merged.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 2
#       1 # TODO: Effectuer la jointure de vos tables si nécessaire
# ----> 2 df_merged = pd.merge(df_main, categories_info, on='category', how='left')
#       3 df_merged.head()
#
# File c:\Users\dearm\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\merge.py:385, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     371     return _cross_merge(
#     372         left_df,
#     373         right_df,
#    (...)    382         validate=validate,
#     383     )
#     384 else:
# --> 385     op = _MergeOperation(
#     386         left_df,
#     387         right_df,
#     388         how=how,
#     389         on=on,
#     390         left_on=left_on,
#     391         right_on=right_on,
#     392         left_index=left_index,
#     393         right_index=right_index,
#     394         sort=sort,
#     395         suffixes=suffixes,
#     396         indicator=indicator,
#     397         validate=validate,
#     398     )
#     399     return op.get_result()
#
# File c:\Users\dearm\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\merge.py:1018, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#    1008     raise MergeError(msg)
#    1010 self.left_on, self.right_on = self._validate_left_right_on(left_on, right_on)
#    1012 (
#    1013     self.left_join_keys,
#    1014     self.right_join_keys,
#    1015     self.join_names,
#    1016     left_drop,
#    1017     right_drop,
# -> 1018 ) = self._get_merge_keys()
#    1020 if left_drop:
#    1021     self.left = self.left._drop_labels_or_levels(left_drop)
#
# File c:\Users\dearm\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\merge.py:1633, in _MergeOperation._get_merge_keys(self)
#    1629 if lk is not None:
#    1630     # Then we're either Hashable or a wrong-length arraylike,
#    1631     #  the latter of which will raise
#    1632     lk = cast(Hashable, lk)
# -> 1633     left_keys.append(left._get_label_or_level_values(lk))
#    1634     join_names.append(lk)
#    1635 else:
#    1636     # work-around for merge_asof(left_index=True)
#
# File c:\Users\dearm\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:1776, in NDFrame._get_label_or_level_values(self, key, axis)
#    1772             values = self.xs(key, axis=first_other_axes)._values
#    1773         elif self._is_level_reference(key, axis=axis):
#    1774             values = self.axes[axis].get_level_values(key)._values
#    1775         else:
# -> 1776             raise KeyError(key)
#    1777
#    1778         # Check for duplicates
#    1779         if values.ndim > 1:
#
# KeyError: 'category'

# %% [markdown]
# ### 5. Consignation des données d'entrée brutes
#
# Sauvegardez l'état brut de vos données d'entrée pour la suite du pipeline.

# %%
# Sauvegarde du fichier brute fusionné si applicable
print("Acquisition terminée avec succès !")
